# %%
"Hello I Am Kemal".split(" ")
# Out:
# ['Hello', 'I', 'Am', 'Kemal']

# %%
import numpy as np
rng = np.random.default_rng()
arrays = [rng.normal(size=(3,4)) for _ in range(10)]
print(arrays, len(arrays), type(arrays), arrays[0].shape)
np.stack(arrays, axis=0).shape
# Out:
# [array([[-0.37258889,  0.23558911, -0.0879741 , -0.72751322],
#        [-1.27928692,  0.34983409, -1.11716314, -1.61789601],
#        [-1.72161014, -1.00786641,  0.62016275, -1.38281704]]), array([[ 0.66813184, -0.77126879,  0.9346065 , -0.42687587],
#        [ 0.22750189,  0.58450269,  2.10913773, -0.26185047],
#        [-0.39527318, -1.51803296, -1.38960996, -1.93338173]]), array([[-1.94626787, -1.6642784 , -2.03838798, -0.77256   ],
#        [-0.2598153 ,  2.37672848,  1.055706  ,  0.20954883],
#        [-0.60522958,  0.79426872,  0.02163529, -0.20483045]]), array([[ 2.79701274,  0.08888946, -2.4412625 ,  0.50137589],
#        [ 0.8616625 ,  0.39315699,  1.63150809,  0.22084818],
#        [-0.21692064, -1.08635208, -1.57003718,  0.89244762]]), array([[-0.6730639 , -0.05555394,  0.00838946,  0.11823058],
#        [-0.1593623 , -0.11548761,  0.76914983, -0.13604236],
#        [ 0.14685544, -0.36691042,  0.43103314,  1.00554537]]), array([[-0.16373003, -0.64878955,  0.11171191, -0.2275465 ],
#        [-0.21436092, -0.49923173,  1.20787823, -1.71463504],
#        [-0.2834683 , -0.36321339, -0.60301186, -1.03531043]]), array([[ 0.9687512 , -0.07084684,  0.20904762, -0.67658264],
#        [-0.91371588,  0.94214205, -1.072566  ,  0.91350027],
#        [-0.20586714,  0.63433588, -0.15142675, -1.27197569]]), array([[-0.01023888, -1.30917233,  1.70721397,  1.18368937],
#        [ 2.07336103,  1.560079  , -1.28288106, -0.98248258],
#        [ 1.03720317,  1.04255549,  0.96387083,  2.1333109 ]]), array([[ 0.07557536, -0.05133742,  1.97380457,  0.25023138],
#        [ 1.0998564 , -2.72876803, -0.38667753,  0.34705149],
#        [ 0.60639167, -0.87235147, -0.22281096,  0.3802315 ]]), array([[ 0.56398493,  0.37210588,  1.17527038, -0.87146269],
#        [-0.2325215 ,  1.58987815,  0.23856538, -1.95870246],
#        [ 0.90435755,  0.75559618,  0.58578178, -0.85728756]])] 10 <class 'list'> (3, 4)
# (10, 3, 4)

# %%
import numpy as np
a = np.array([1, 2])
b = np.array([3, 4])
c = np.array([5, 6])
print(np.concatenate((a, b,c)))
# Out:
# [1 2 3 4 5 6]

# %%
def check_type(variable):
  """
  Checks if a variable is a list or a string.

  Args:
    variable: The variable to check.

  Returns:
    "list" if the variable is a list, "string" if it's a string, 
    and "other" otherwise.
  """
  if isinstance(variable, list):
    return "list"
  elif isinstance(variable, str):
    return "string"
  elif isinstance(variable, int):
    return "integer"
  else:
    return "other"

# Examples
my_list = [1, 2, 3]
my_string = "hello"
my_integer = 10

print(f"The type of my_list is: {check_type(my_list)}")
print(f"The type of my_string is: {check_type(my_string)}")
print(f"The type of my_integer is: {check_type(my_integer)}")
# Out:
# The type of my_list is: list
# The type of my_string is: string
# The type of my_integer is: integer

# %%
#buildTable(caption,header,body,footer) -> string
#caption -> string
#header -> list of lists
#body -> list of lists
#footer -> list of lists
#Creates HTML table with caption Caption, using header, body, and footer as such.
#header, body, footer: main list is all data, each inner list is a row, each list value is a collumn for that row
def buildTable(caption,header,body,footer):
            tableMultiline = '''\n\t<table>
            <caption> _CAPTION_ </caption>
            <thead> _HEAD_
            </thead>
            <tbody> _BODY_
            </tbody>
            <tfoot> _FOOT_
            </tfoot>
        </table>\n'''
            multHead = ""
            multBody = ""
            multFoot = ""
            for item in header:
                multHead += "\n\t\t<tr>"
                for cell in item:
                    multHead += "<th>" + str(cell) + "</th>"
                multHead += "</tr>"
            for item in body:
                multBody += "\n\t\t<tr>"
                for cell in item:
                    multBody += "<td>" + str(cell) + "</td>"
                multBody += "</tr>"
            for item in footer:
                multFoot += "\n\t\t<tr>"
                for cell in item:
                    multFoot += "<td>" + str(cell) + "</td>"
                multFoot += "</tr>"
            tableMultiline = tableMultiline.replace("_CAPTION_",caption)
            tableMultiline = tableMultiline.replace("_HEAD_",multHead)
            tableMultiline = tableMultiline.replace("_BODY_",multBody)
            tableMultiline = tableMultiline.replace("_FOOT_",multFoot)
            return tableMultiline

# %%
with open("pokemon/pokemon.csv", "r") as pokeData:
    pokeData = pokeData.read()
    pokeData = pokeData.split("\n")
    pokeDataSplit = []
    for item in pokeData:
        pokeDataSplit.append(item.split(","))
typesList = ["bug","dragon","electric","fairy","fighting","fire","flying","ghost","grass","ground","ice","normal","poison","psychic","rock","steel","water"]
grassList = [pokemon for pokemon in pokeDataSplit if "grass" in [type_.lower() for type_ in pokemon]]
bigTypesListForTable = []
for item in typesList:
    bigTypesListForTable.append([pokemon for pokemon in pokeDataSplit if f"{item}" in [type_.lower() for type_ in pokemon]])
print(bigTypesListForTable)


for i in range(len(typesList)):
    print(buildTable(f"{typesList[i]}",[pokeDataSplit[0]],[bigTypesListForTable[i]],[]))
# Out:
# [[['10', 'Caterpie', 'Bug', '', '195', '45', '30', '35', '20', '20', '45', '1', 'False'], ['11', 'Metapod', 'Bug', '', '205', '50', '20', '55', '25', '25', '30', '1', 'False'], ['12', 'Butterfree', 'Bug', 'Flying', '395', '60', '45', '50', '90', '80', '70', '1', 'False'], ['13', 'Weedle', 'Bug', 'Poison', '195', '40', '35', '30', '20', '20', '50', '1', 'False'], ['14', 'Kakuna', 'Bug', 'Poison', '205', '45', '25', '50', '25', '25', '35', '1', 'False'], ['15', 'Beedrill', 'Bug', 'Poison', '395', '65', '90', '40', '45', '80', '75', '1', 'False'], ['46', 'Paras', 'Bug', 'Grass', '285', '35', '70', '55', '45', '55', '25', '1', 'False'], ['47', 'Parasect', 'Bug', 'Grass', '405', '60', '95', '80', '60', '80', '30', '1', 'False'], ['48', 'Venonat', 'Bug', 'Poison', '305', '60', '55', '50', '40', '55', '45', '1', 'False'], ['49', 'Venomoth', 'B
479', '83', '80', '75', '70', '70', '101', '1', 'False']</td><td>['21', 'Spearow', 'Normal', 'Flying', '262', '40', '60', '30', '31', '31', '70', '1', 'False']</td><td>['22', 'Fearow', 'Normal', 'Flying', '442', '65', '90', '65', '61', '61', '100', '1', 'False']</td><td>['41', 'Zubat', 'Poison', 'Flying', '245', '40', '45', '35', '30', '40', '55', '1', 'False']</td><td>['42', 'Golbat', 'Poison', 'Flying', '455', '75', '80', '70', '65', '75', '90', '1', 'False']</td><td>['83', "Farfetch'd", 'Normal', 'Flying', '352', '52', '65', '55', '58', '62', '60', '1', 'False']</td><td>['84', 'Doduo', 'Normal', 'Flying', '310', '35', '85', '45', '35', '35', '75', '1', 'False']</td><td>['85', 'Dodrio', 'Normal', 'Flying', '460', '60', '110', '70', '60', '60', '100', '1', 'False']</td><td>['123', 'Scyther', 'Bug', 'Flying', '500', '70', '110', '80', '55', '80', '105', '1', 'False']</td><td>['130', 'Gyarados', 'Water', 'Flying', '540', '95', '125', '79', '60', '100', '81', '1', 'False']</td><td>['142', 'Aerodactyl', 'Rock', 'Flying', '515', '80', '105', '65', '60', '75', '130', '1', 'False']</td><td>['144', 'Articuno', 'Ice', 'Flying', '580', '90', '85', '100', '95', '125', '85', '1', 'True']</td><td>['145', 'Zapdos', 'Electric', 'Flying', '580', '90', '90', '85', '125', '90', '100', '1', 'True']</td><td>['146', 'Moltres', 'Fire', 'Flying', '580', '90', '100', '90', '125', '85', '90', '1', 'True']</td><td>['149', 'Dragonite', 'Dragon', 'Flying', '600', '91', '134', '95', '100', '100', '80', '1', 'False']</td></tr>
#             </tbody>
#             <tfoot>
#             </tfoot>
#         </table>
#
#
# 	<table>
#             <caption> ghost </caption>
#             <thead>
# 		<tr><th>#</th><th>Name</th><th>Type 1</th><th>Type 2</th><th>Total</th><th>HP</th><th>Attack</th><th>Defense</th><th>Sp. Atk</th><th>Sp. Def</th><th>Speed</th><th>Generation</th><th>Legendary</th></tr>
#             </thead>
#             <tbody>
# 		<tr><td>['92', 'Gastly', 'Ghost', 'Poison', '310', '30', '35', '30', '100', '35', '80', '1', 'False']</td><td>['93', 'Haunter', 'Ghost', 'Poison', '405', '45', '50', '45', '115', '55', '95', '1', 'False']</td><td>['94', 'Gengar', 'Ghost', 'Poison', '500', '60', '65', '60', '130', '75', '110', '1', 'False']</td></tr>
#             </tbody>
#             <tfoot>
#             </tfoot>
#         </table>
#
#
# 	<table>
#             <caption> grass </caption>
#             <thead>
# 		<tr><th>#</th><th>Name</th><th>Type 1</th><th>Type 2</th><th>Total</th><th>HP</th><th>Attack</th><th>Defense</th><th>Sp. Atk</th><th>Sp. Def</th><th>Speed</th><th>Generation</th><th>Legendary</th></tr>
#             </thead>
#             <tbody>
# 		<tr><td>['1', 'Bulbasaur', 'Grass', 'Poison', '318', '45', '49', '49', '65', '65', '45', '1', 'False']</td><td>['2', 'Ivysaur', 'Grass', 'Poison', '405', '60', '62', '63', '80', '80', '60', '1', 'False']</td><td>['3', 'Venusaur', 'Grass', 'Poison', '525', '80', '82', '83', '100', '100', '80', '1', 'False']</td><td>['43', 'Oddish', 'Grass', 'Poison', '320', '45', '50', '55', '75', '65', '30', '1', 'False']</td><td>['44', 'Gloom', 'Grass', 'Poison', '395', '60', '65', '70', '85', '75', '40', '1', 'False']</td><td>['45', 'Vileplume', 'Grass', 'Poison', '490', '75', '80', '85', '110', '90', '50', '1', 'False']</td><td>['46', 'Paras', 'Bug', 'Grass', '285', '35', '70', '55', '45', '55', '25', '1', 'False']</td><td>['47', 'Parasect', 'Bug', 'Grass', '405', '60', '95', '80', '60', '80', '30', '1', 'False']</td><td>['69', 'Bellsprout', 'Grass', 'Poison', '300', '50', '75', '35', '70', '30', '40', '1', 'False']</td><td>['70', 'Weepinbell', 'Grass', 'Poison', '390', '65', '90', '50', '85', '45', '55', '1', 'False']
21', 'Spearow', 'Normal', 'Flying', '262', '40', '60', '30', '31', '31', '70', '1', 'False']</td><td>['22', 'Fearow', 'Normal', 'Flying', '442', '65', '90', '65', '61', '61', '100', '1', 'False']</td><td>['39', 'Jigglypuff', 'Normal', 'Fairy', '270', '115', '45', '20', '45', '25', '20', '1', 'False']</td><td>['40', 'Wigglytuff', 'Normal', 'Fairy', '435', '140', '70', '45', '85', '50', '45', '1', 'False']</td><td>['52', 'Meowth', 'Normal', '', '290', '40', '45', '35', '40', '40', '90', '1', 'False']</td><td>['53', 'Persian', 'Normal', '', '440', '65', '70', '60', '65', '65', '115', '1', 'False']</td><td>['83', "Farfetch'd", 'Normal', 'Flying', '352', '52', '65', '55', '58', '62', '60', '1', 'False']</td><td>['84', 'Doduo', 'Normal', 'Flying', '310', '35', '85', '45', '35', '35', '75', '1', 'False']</td><td>['85', 'Dodrio', 'Normal', 'Flying', '460', '60', '110', '70', '60', '60', '100', '1', 'False']</td><td>['108', 'Lickitung', 'Normal', '', '385', '90', '55', '75', '60', '75', '30', '1', 'False']</td><td>['113', 'Chansey', 'Normal', '', '450', '250', '5', '5', '35', '105', '50', '1', 'False']</td><td>['115', 'Kangaskhan', 'Normal', '', '490', '105', '95', '80', '40', '80', '90', '1', 'False']</td><td>['128', 'Tauros', 'Normal', '', '490', '75', '100', '95', '40', '70', '110', '1', 'False']</td><td>['132', 'Ditto', 'Normal', '', '288', '48', '48', '48', '48', '48', '48', '1', 'False']</td><td>['133', 'Eevee', 'Normal', '', '325', '55', '55', '50', '45', '65', '55', '1', 'False']</td><td>['137', 'Porygon', 'Normal', '', '395', '65', '60', '70', '85', '75', '40', '1', 'False']</td><td>['143', 'Snorlax', 'Normal', '', '540', '160', '110', '65', '65', '110', '30', '1', 'False']</td></tr>
#             </tbody>
#             <tfoot>
#             </tfoot>
#         </table>
#
#
# 	<table>
#             <caption> poison </caption>
#             <thead>
# 		<tr><th>#</th><th>Name</th><th>Type 1</th><th>Type 2</th><th>Total</th><th>HP</th><th>Attack</th><th>Defense</th><th>Sp. Atk</th><th>Sp. Def</th><th>Speed</th><th>Generation</th><th>Legendary</th></tr>
#             </thead>
#             <tbody>
# 		<tr><td>['1', 'Bulbasaur', 'Grass', 'Poison', '318', '45', '49', '49', '65', '65', '45', '1', 'False']</td><td>['2', 'Ivysaur', 'Grass', 'Poison', '405', '60', '62', '63', '80', '80', '60', '1', 'False']</td><td>['3', 'Venusaur', 'Grass', 'Poison', '525', '80', '82', '83', '100', '100', '80', '1', 'False']</td><td>['13', 'Weedle', 'Bug', 'Poison', '195', '40', '35', '30', '20', '20', '50', '1', 'False']</td><td>['14', 'Kakuna', 'Bug', 'Poison', '205', '45', '25', '50', '25', '25', '35', '1', 'False']</td><td>['15', 'Beedrill', 'Bug', 'Poison', '395', '65', '90', '40', '45', '80', '75', '1', 'False']</td><td>['23', 'Ekans', 'Poison', '', '288', '35', '60', '44', '40', '54', '55', '1', 'False']</td><td>['24', 'Arbok', 'Poison', '', '438', '60', '85', '69', '65', '79', '80', '1', 'False']</td><td>['29', 'Nidoranâ™€', 'Poison', '', '275', '55', '47', '52', '40', '40', '41', '1', 'False']</td><td>['30', 'Nidorina', 'Poison', '', '365', '70', '62', '67', '55', '55', '56', '1', 'False']</td><td>['31', 'Nidoqueen', 'Poison', 'Ground', '505', '90', '92', '87', '75', '85', '76', '1', 'False']</td><td>['32', 'Nidoranâ™‚', 'Poison', '', '273', '46', '57', '40', '40', '40', '50', '1', 'False']</td><td>['33', 'Nidorino', 'Poison', '', '365', '61', '72', '57', '55', '55', '65', '1', 'False']</td><td>['34', 'Nidoking', 'Poison', 'Ground', '505', '81', '102', '77', '85', '75', '85', '1', 'False']</td><td>['41', 'Zubat', 'Poison', 'Flying', '245', '40', '45', '35', '30', '40', '55', '1', 'False']</td><td>['42', 'Golbat', 'Poison', 'Flying', '455', '75', '80', '70', '65', '75', '90', '1', 'False']</td><td>['43', 'Oddish', 'Grass', 'Poison', '320', '45', '50', '55', '75', '65', '30', '1', 'False']</td><td>['44', 'Gloom', 'Grass', 'Poison', '395', '60', '65', '70', '85', '75', '40', '1', 'False']</td><td>['45', 'Vileplume', 'Grass', 'Poison', '490', '75', '80', '85', '110', '90', '50', '1', 'False']</td><td>['48', 'Venonat', 'Bug', 'Poison', '305', '60', '55', '50', '40', '55', '45', '1', 'False']</td><td>['49', 'Venomoth', 'Bug', 'Poison', '450', '70', '65', '60', '90', '75', '90', '1', 'False']</td><td>['69', 'Bellsprout', 'Grass', 'Poison', '300', '50', '75', '35', '70', '30', '40', '1', 'False']</td><td>['70', 'Weepinbell', 'Grass', 'Poison', '390', '65', '90', '50', '85', '45', '55', '1', 'False']</td><td>['71', 'Victreebel', 'Grass', 'Poison', '490', '80', '105', '65', '100', '70', '70', '1', 'False']</td><td>['72', 'Tentacool', 'Water', 'Poison', '335', '40', '40', '35', '50', '100', '70', '1', 'False']</td><td>['73', 'Tentacruel', 'Water', 'Poison', '515', '80', '70', '65', '80', '120', '100', '1', 'False']</td><td>['88', 'Grimer', 'Poison', '', '325', '80', '80', '50', '40', '50', '25', '1', 'False']</td><td>['89', 'Muk', 'Poison', '', '500', '105', '105', '75', '65', '100', '50', '1', 'False']</td><td>['92', 'Gastly', 'Ghost', 'Poison', '310', '30', '35', '30', '100', '35', '80', '1', 'False']</td><td>['93', 'Haunter', 'Ghost', 'Poison', '405', '45', '50', '45', '115', '55', '95', '1', 'False']</td><td>['94', 'Gengar', 'Ghost', 'Poison', '500', '60', '65', '60', '130', '75', '110', '1', 'False']</td><td>['109', 'Koffing', 'Poison', '', '340', '40', '65', '95', '60', '45', '35', '1', 'False']</td><td>['110', 'Weezing', 'Poison', '', '490', '65', '90', '120', '85', '70', '60', '1', 'False']</td></tr>
#             </tbody>
#             <tfoot>
#             </tfoot>
#         </table>
#
#
# 	<table>
#             <caption> psychic </caption>
#             <thead>
# 		<tr><th>#</th><th>Name</th><th>Type 1</th><th>Type 2</th><th>Total</th><th>HP</th><th>Attack</th><th>Defense</th><th>Sp. Atk</th><th>Sp. Def</th><th>Speed</th><th>Generation</th><th>Legendary</th></tr>
#             </thead>
#             <tbody>
# 		<tr><td>['63', 'Abra', 'Psychic', '', '310', '25', '20', '15', '105', '55', '90', '1', 'False']</td><td>['64', 'Kadabra', 'Psychic', '', '400', '40', '35', '30', '120', '70', '105', '1', 'False']</td><td>['65', 'Alakazam', 'Psychic', '', '500', '55', '50', '45', '135', '95', '120', '1', 'False']</td><td>['79', 'Slowpoke', 'Water', 'Psychic', '315', '90', '65', '65', '40', '40', '15', '1', 'False']</td><td>['80', 'Slowbro', 'Water', 'Psychic', '490', '95', '75', '110', '100', '80', '30', '1', 'False']</td><td>['96', 'Drowzee', 'Psychic', '', '328', '60', '48', '45', '43', '90', '42', '1', 'False']</td><td>['97', 'Hypno', 'Psychic', '', '483', '85', '73', '70', '73', '115', '67', '1', 'False']</td><td>['102', 'Exeggcute', 'Grass', 'Psychic', '325', '60', '40', '80', '60', '45', '40', '1', 'False']</td><td>['103', 'Exeggutor', 'Grass', 'Psychic', '520', '95', '95', '85', '125', '65', '55', '1', 'False']</td><td>['121', 'Starmie', 'Water', 'Psychic', '520', '60', '75', '85', '100', '85', '115', '1', 'False']</td><td>['122', 'Mr. Mime', 'Psychic', 'Fairy', '460', '40', '45', '65', '100', '120', '90', '1', 'False']</td><td>['124', 'Jynx', 'Ice', 'Psychic', '455', '65', '50', '35', '115', '95', '95', '1', 'False']</td><td>['150', 'Mewtwo', 'Psychic', '', '680', '106', '110', '90', '154', '90', '130', '1', 'True']</td><td>['151', 'Mew', 'Psychic', '', '600', '100', '100', '100', '100', '100', '100', '1', 'False']</td></tr>
#             </tbody>
#             <tfoot>
#             </tfoot>
#         </table>
#
#
# 	<table>
#             <caption> rock </caption>
#             <thead>
# 		<tr><th>#</th><th>Name</th><th>Type 1</th><th>Type 2</th><th>Total</th><th>HP</th><th>Attack</th><th>Defense</th><th>Sp. Atk</th><th>Sp. Def</th><th>Speed</th><th>Generation</th><th>Legendary</th></tr>
#             </thead>
#             <tbody>
# 		<tr><td>['74', 'Geodude', 'Rock', 'Ground', '300', '40', '80', '100', '30', '30', '20', '1', 'False']</td><td>['75', 'Graveler', 'Rock', 'Ground', '390', '55', '95', '115', '45', '45', '35', '1', 'False']</td><td>['76', 'Golem', 'Rock', 'Ground', '495', '80', '120', '130', '55', '65', '45', '1', 'False']</td><td>['95', 'Onix', 'Rock', 'Ground', '385', '35', '45', '160', '30', '45', '70', '1', 'False']</td><td>['111', 'Rhyhorn', 'Ground', 'Rock', '345', '80', '85', '95', '30', '30', '25', '1', 'False']</td><td>['112', 'Rhydon', 'Ground', 'Rock', '485', '105', '130', '120', '45', '45', '40', '1', 'False']</td><td>['138', 'Omanyte', 'Rock', 'Water', '355', '35', '40', '100', '90', '55', '35', '1', 'False']</td><td>['139', 'Omastar', 'Rock', 'Water', '495', '70', '60', '125', '115', '70', '55', '1', 'False']</td><td>['140', 'Kabuto', 'Rock', 'Water', '355', '30', '80', '90', '55', '45', '55', '1', 'False']</td><td>['141', 'Kabutops', 'Rock', 'Water', '495', '60', '115', '105', '65', '70', '80', '1', 'False']</td><td>['142', 'Aerodactyl', 'Rock', 'Flying', '515', '80', '105', '65', '60', '75', '130', '1', 'False']</td></tr>
#             </tbody>
#             <tfoot>
#             </tfoot>
#         </table>
#
#
# 	<table>
#             <caption> steel </caption>
#             <thead>
# 		<tr><th>#</th><th>Name</th><th>Type 1</th><th>Type 2</th><th>Total</th><th>HP</th><th>Attack</th><th>Defense</th><th>Sp. Atk</th><th>Sp. Def</th><th>Speed</th><th>Generation</th><th>Legendary</th></tr>
#             </thead>
#             <tbody>
# 		<tr><td>['81', 'Magnemite', 'Electric', 'Steel', '325', '25', '35', '70', '95', '55', '45', '1', 'False']</td><td>['82', 'Magneton', 'Electric', 'Steel', '465', '50', '60', '95', '120', '70', '70', '1', 'False']</td></tr>
#             </tbody>
#             <tfoot>
#             </tfoot>
#         </table>
#
#
# 	<table>
#             <caption> water </caption>
#             <thead>
# 		<tr><th>#</th><th>Name</th><th>Type 1</th><th>Type 2</th><th>Total</th><th>HP</th><th>Attack</th><th>Defense</th><th>Sp. Atk</th><th>Sp. Def</th><th>Speed</th><th>Generation</th><th>Legendary</th></tr>
#             </thead>
#             <tbody>
# 		<tr><td>['7', 'Squirtle', 'Water', '', '314', '44', '48', '65', '50', '64', '43', '1', 'False']</td><td>['8', 'Wartortle', 'Water', '', '405', '59', '63', '80', '65', '80', '58', '1', 'False']</td><td>['9', 'Blastoise', 'Water', '', '530', '79', '83', '100', '85', '105', '78', '1', 'False']</td><td>['54', 'Psyduck', 'Water', '', '320', '50', '52', '48', '65', '50', '55', '1', 'False']</td><td>['55', 'Golduck', 'Water', '', '500', '80', '82', '78', '95', '80', '85', '1', 'False']</td><td>['60', 'Poliwag', 'Water', '', '300', '40', '50', '40', '40', '40', '90', '1', 'False']</td><td>['61', 'Poliwhirl', 'Water', '', '385', '65', '65', '65', '50', '50', '90', '1', 'False']</td><td>['62', 'Poliwrath', 'Water', 'Fighting', '510', '90', '95', '95', '70', '90', '70', '1', 'False']</td><td>['72', 'Tentacool', 'Water', 'Poison', '335', '40', '40', '35', '50', '100', '70', '1', 'False']</td><td>['73', 'Tentacruel', 'Water', 'Poison', '515', '80', '70', '65', '80', '120', '100', '1', 'False']</td><td>['79', 'Slowpoke', 'Water', 'Psychic', '315', '90', '65', '65', '40', '40', '15', '1', 'False']</td><td>['80', 'Slowbro', 'Water', 'Psychic', '490', '95', '75', '110', '100', '80', '30', '1', 'False']</td><td>['86', 'Seel', 'Water', '', '325', '65', '45', '55', '45', '70', '45', '1', 'False']</td><td>['87', 'Dewgong', 'Water', 'Ice', '475', '90', '70', '80', '70', '95', '70', '1', 'False']</td><td>['90', 'Shellder', 'Water', '', '305', '30', '65', '100', '45', '25', '40', '1', 'False']</td><td>['91', 'Cloyster', 'Water', 'Ice', '525', '50', '95', '180', '85', '45', '70', '1', 'False']</td><td>['98', 'Krabby', 'Water', '', '325', '30', '105', '90', '25', '25', '50', '1', 'False']</td><td>['99', 'Kingler', 'Water', '', '475', '55', '130', '115', '50', '50', '75', '1', 'False']</td><td>['116', 'Horsea', 'Water', '', '295', '30', '40', '70', '70', '25', '60', '1', 'False']</td><td>['117', 'Seadra', 'Water', '', '440', '55', '65', '95', '95', '45', '85', '1', 'False']</td><td>['118', 'Goldeen', 'Water', '', '320', '45', '67', '60', '35', '50', '63', '1', 'False']</td><td>['119', 'Seaking', 'Water', '', '450', '80', '92', '65', '65', '80', '68', '1', 'False']</td><td>['120', 'Staryu', 'Water', '', '340', '30', '45', '55', '70', '55', '85', '1', 'False']</td><td>['121', 'Starmie', 'Water', 'Psychic', '520', '60', '75', '85', '100', '85', '115', '1', 'False']</td><td>['129', 'Magikarp', 'Water', '', '200', '20', '10', '55', '15', '20', '80', '1', 'False']</td><td>['130', 'Gyarados', 'Water', 'Flying', '540', '95', '125', '79', '60', '100', '81', '1', 'False']</td><td>['131', 'Lapras', 'Water', 'Ice', '535', '130', '85', '80', '85', '95', '60', '1', 'False']</td><td>['134', 'Vaporeon', 'Water', '', '525', '130', '65', '60', '110', '95', '65', '1', 'False']</td><td>['138', 'Omanyte', 'Rock', 'Water', '355', '35', '40', '100', '90', '55', '35', '1', 'False']</td><td>['139', 'Omastar', 'Rock', 'Water', '495', '70', '60', '125', '115', '70', '55', '1', 'False']</td><td>['140', 'Kabuto', 'Rock', 'Water', '355', '30', '80', '90', '55', '45', '55', '1', 'False']</td><td>['141', 'Kabutops', 'Rock', 'Water', '495', '60', '115', '105', '65', '70', '80', '1', 'False']</td></tr>
#             </tbody>
#             <tfoot>
#             </tfoot>
#         </table>

# %%
listie = []
listie.append("Hello!" + "Baiii")
